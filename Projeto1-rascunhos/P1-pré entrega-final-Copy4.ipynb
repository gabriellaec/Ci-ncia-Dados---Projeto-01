# %% [markdown]
# <h1><center>Ciência dos Dados - PROJETO 1</center></h1>
# <h2><center>Gabriella Escobar Cukier</center></h2>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1><center>União Europeia</center></h1>

# %% [markdown]
# Considerado um dos mais importantes blocos econômicso do mundo, a União Europeia é formada por 28 países. Entre eles, há ivre circulação de bens, mercadorias e pessoas e o uso de uma moeda única.

# %% [markdown]
# ## Pergunta (s) a ser respondida
# ### Como a entrada na União Europeia afeta o desemprego em um país?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
# Segundo o artigo "The EU Single Market: Impact on Member States", conduzido pela LE Europe, a União Europeia é um bloco econômico com um grande nível de integração. Isso traz consequências benéficas como melhorias econômicas e em índices internos da qualidade de vida de cada país.
# É o caso da Polônia, como mostrado no artigo "POLAND IN THE EUROPEAN UNION. TEN YEARS OF MEMBERSHIP", da Universidade de Varsóvia. Ele estuda as consequências econômicas da entrada da Polônia na União Europeia.
# Segundo o estudo, a entrada no bloco econômico causou um significativo aumento das exportações, devido ao acordo de livre circulação de mercadorias. Como consequência, a economia do pais melhorou.
# Levando em conta tais transformações no cenário econômico, este trabalho visa estudar como a entrada de um país na União Europeia afeta seu nível de desemprego.
# Também serão analisadas alguns fatores relevantes para a mudança deste indíce, dentre eles o crescimento do GDP, o nível de exportações e os investimentos internos em infraestrutura do país.

# %% [markdown]
# Referências dos artigos: http://www.amchameu.eu/sites/default/files/amcham_eu_single_market_web.pdf ; https://www.ucm.es/data/cont/media/www/pag-78913/UNISCIDP40-1Katarzyna%20K.pdf

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# Os dados usados foram retirados do site GapMinder (https://www.gapminder.org/data/). Os seguintes índices serão estudados: IDH, GDP per capita, desemprego (pessoas com mais de 15 anos), exportações (% do GDP), crescimento anual do GDP, investimentos internos (% do GDP).

# %% [markdown]
# ## Análise de dados

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
# acesso aos dataframes
idh = pd.read_excel('idh.xlsx')
gdp= pd.read_excel('gdp_capta.xlsx')
unemployment=pd.read_excel('unemployment.xlsx')
investimento=pd.read_excel('inestimentos.xlsx')
dGDP=pd.read_excel('aumento_GDP.xlsx')
exportacao=pd.read_excel('exportacao.xlsx')

# %% [markdown]
# Para filtrar os países que fazem parte da União Europeia, foi usada uma variável qualitativa, em que 0 indica o não pertencimento e 1 o pertencimento ao bloco em questão

# %%
paises = pd.read_excel('paises_UE2.xlsx')
paises.head()
# Out:
#        country
# 0  Afghanistan
# 1      Albania
# 2      Algeria
# 3      Andorra
# 4       Angola

# %%
paises['EU']=0
paises.head()
# Out:
#        country  EU
# 0  Afghanistan   0
# 1      Albania   0
# 2      Algeria   0
# 3      Andorra   0
# 4       Angola   0

# %%
paises.loc[[('Andorra','Australia', 'Brunei','Canada','Iceland','Israel','Japan','Lichtenstein','South Korea')],['EU']]=3
#paises.loc[(('Cyprus'),('Czech Republic'), ('Estonia'),('Hungary'),('Latvia'),('Lithuania'),('Malta'),('Poland'),('Slovak Republic'),('Slovenia')),('EU')]==2
#paises.loc[(('Austria'),('Belgium'),('Bulgaria'),('Croatia'),('Cyprus'),('Czech Republic'),('Denmark'), ('Estonia'),('Finland'),('France'),('Germany'),('Greece'),('Hungary'),('Ireland'),('Italy'),('Latvia'),('Lithuania'),('Luxembourg'),('Malta'),('Netherlands'),('Poland'),('Portugal'),('Romania'),('Slovak Republic'),('Slovenia'),('Spain'),('Sweden'),('United Kingdom')),('EU')]==1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-70650c0c00ea> in <module>
# ----> 1 paises.loc[[('Andorra','Australia', 'Brunei','Canada','Iceland','Israel','Japan','Lichtenstein','South Korea')],['EU']]=3
#       2 #paises.loc[(('Cyprus'),('Czech Republic'), ('Estonia'),('Hungary'),('Latvia'),('Lithuania'),('Malta'),('Poland'),('Slovak Republic'),('Slovenia')),('EU')]==2
#       3 #paises.loc[(('Austria'),('Belgium'),('Bulgaria'),('Croatia'),('Cyprus'),('Czech Republic'),('Denmark'), ('Estonia'),('Finland'),('France'),('Germany'),('Greece'),('Hungary'),('Ireland'),('Italy'),('Latvia'),('Lithuania'),('Luxembourg'),('Malta'),('Netherlands'),('Poland'),('Portugal'),('Romania'),('Slovak Republic'),('Slovenia'),('Spain'),('Sweden'),('United Kingdom')),('EU')]==1
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     186         else:
#     187             key = com._apply_if_callable(key, self.obj)
# --> 188         indexer = self._get_setitem_indexer(key)
#     189         self._setitem_with_indexer(indexer, value)
#     190
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     164         if isinstance(key, tuple):
#     165             try:
# --> 166                 return self._convert_tuple(key, is_setter=True)
#     167             except IndexingError:
#     168                 pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_tuple(self, key, is_setter)
#     245                 if i >= self.obj.ndim:
#     246                     raise IndexingError('Too many indexers')
# --> 247                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     248                 keyidx.append(idx)
#     249         return tuple(keyidx)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "[('Andorra', 'Australia', 'Brunei', 'Canada', 'Iceland', 'Israel', 'Japan', 'Lichtenstein', 'South Korea')] not in index"

# %%
paises['EU'].value_counts()
# Out:
# 0    159
# 1     28
# Name: EU, dtype: int64

# %% [markdown]
# ## Escolha dos países a serem analisados

# %% [markdown]
# Oficialmente, a União Europeia foi fundada em 1992, mas sua formação fundamentou-se em um longo processo atrelado a acordos intergovernamentais anteriores.
# O número de países membros foi aumentando ao longo dos anos. Em 2004 ocorreu a entrada no bloco com o maior número de membros. Por esse motivo, o ano em questão, assim como os países que participaram dessa adesão foram  selecionados como base para uma análise mais aprofundada das consequências da entrada no bloco.

# %% [markdown]
# Os países que entraram no ano de 2004 foram: Estónia, Letónia, Lituânia, Chipre, Malta, Polónia, República Checa, Hungria e Eslováquia e Eslovênia.

# %% [markdown]
# O objetivo do projeto é estudar o efeito da entrada no bloco ecoômico em questão. Assim, é importante comparar os dados com aqueles de outros países. Para uma melhor comparação, serão escolhidos países não pertencentes ao bloco que possuem um nível socioeconômico semelhante. Para isso, será levado em conta o IDH e GDP per capita.

# %%
paises_gdp=gdp.loc[:,[(2015)]]
paises_gdp = paises_gdp.rename(columns = {2015:'GDP_2015'})
paises_gdp.head()
# Out:
#    GDP_2015
# 0      1750
# 1     11000
# 2     13700
# 3     46600
# 4      6230

# %%
paises_idh=idh.loc[:,[(2015)]]
paises_idh = paises_idh.rename(columns = {2015:'IDH_2015'})
paises_idh.head()
# Out:
#    IDH_2015
# 0     0.479
# 1     0.764
# 2     0.745
# 3     0.858
# 4     0.533

# %% [markdown]
# Para facilitar a comparação destas variáveis qualitativas de diferentes países, foram estabelecidas faixas de valores

# %%
faixas_idh = pd.cut(paises_idh['IDH_2015'], bins=20)
faixas_gdp=  pd.cut(paises_gdp['GDP_2015'], bins=20)
faixas_idh.head()
# Out:
# 0    (0.471, 0.501]
# 1      (0.74, 0.77]
# 2      (0.74, 0.77]
# 3     (0.83, 0.859]
# 4    (0.531, 0.561]
# Name: IDH_2015, dtype: category
# Categories (20, interval[float64]): [(0.351, 0.382] < (0.382, 0.412] < (0.412, 0.442] < (0.442, 0.471] ... (0.83, 0.859] < (0.859, 0.889] < (0.889, 0.919] < (0.919, 0.949]]

# %%
df = paises.join(paises_gdp, how='inner', lsuffix=' ', rsuffix=' ')
df.head(10)
# Out:
#                country  EU  selecao  GDP_2015
# 0          Afghanistan   0        0      1750
# 1              Albania   0        0     11000
# 2              Algeria   0        0     13700
# 3              Andorra   0        2     46600
# 4               Angola   0        0      6230
# 5  Antigua and Barbuda   0        0     20100
# 6            Argentina   0        0     19100
# 7              Armenia   0        0      8180
# 8            Australia   0        2     43800
# 9              Austria   1        0     44100

# %%
data = df.join(paises_idh, how="inner")
data.head(10)
# Out:
#                country  EU  selecao  GDP_2015  IDH_2015
# 0          Afghanistan   0        0      1750     0.479
# 1              Albania   0        0     11000     0.764
# 2              Algeria   0        0     13700     0.745
# 3              Andorra   0        2     46600     0.858
# 4               Angola   0        0      6230     0.533
# 5  Antigua and Barbuda   0        0     20100     0.786
# 6            Argentina   0        0     19100     0.827
# 7              Armenia   0        0      8180     0.743
# 8            Australia   0        2     43800     0.939
# 9              Austria   1        0     44100     0.893

# %%
dataf = data.join(faixas_idh, how="inner", lsuffix='', rsuffix='_faixas')
dataf.head(10)
# Out:
#                country  EU  selecao  GDP_2015  IDH_2015 IDH_2015_faixas
# 0          Afghanistan   0        0      1750     0.479  (0.471, 0.501]
# 1              Albania   0        0     11000     0.764    (0.74, 0.77]
# 2              Algeria   0        0     13700     0.745    (0.74, 0.77]
# 3              Andorra   0        2     46600     0.858   (0.83, 0.859]
# 4               Angola   0        0      6230     0.533  (0.531, 0.561]
# 5  Antigua and Barbuda   0        0     20100     0.786     (0.77, 0.8]
# 6            Argentina   0        0     19100     0.827     (0.8, 0.83]
# 7              Armenia   0        0      8180     0.743    (0.74, 0.77]
# 8            Australia   0        2     43800     0.939  (0.919, 0.949]
# 9              Austria   1        0     44100     0.893  (0.889, 0.919]

# %%
dfaixas = dataf.join(faixas_gdp, how="inner", lsuffix='', rsuffix='_faixas')
dfaixas.head(10)
# Out:
#                country  EU  selecao  GDP_2015  IDH_2015 IDH_2015_faixas  \
# 0          Afghanistan   0        0      1750     0.479  (0.471, 0.501]
# 1              Albania   0        0     11000     0.764    (0.74, 0.77]
# 2              Algeria   0        0     13700     0.745    (0.74, 0.77]
# 3              Andorra   0        2     46600     0.858   (0.83, 0.859]
# 4               Angola   0        0      6230     0.533  (0.531, 0.561]
# 5  Antigua and Barbuda   0        0     20100     0.786     (0.77, 0.8]
# 6            Argentina   0        0     19100     0.827     (0.8, 0.83]
# 7              Armenia   0        0      8180     0.743    (0.74, 0.77]
# 8            Australia   0        2     43800     0.939  (0.919, 0.949]
# 9              Austria   1        0     44100     0.893  (0.889, 0.919]
#
#        GDP_2015_faixas
# 0   (503.623, 6591.85]
# 1   (6591.85, 12560.7]
# 2  (12560.7, 18529.55]
# 3  (42404.95, 48373.8]
# 4   (503.623, 6591.85]
# 5  (18529.55, 24498.4]
# 6  (18529.55, 24498.4]
# 7   (6591.85, 12560.7]
# 8  (42404.95, 48373.8]
# 9  (42404.95, 48373.8]

# %%
europeus=dfaixas[dfaixas['EU']==1]
europeus.head()
# Out:
#      country  EU  selecao  GDP_2015  IDH_2015 IDH_2015_faixas  \
# 9    Austria   1        0     44100     0.893  (0.889, 0.919]
# 16   Belgium   1        0     41700     0.896  (0.889, 0.919]
# 25  Bulgaria   1        0     17000     0.794     (0.77, 0.8]
# 42   Croatia   1        0     20600     0.827     (0.8, 0.83]
# 44    Cyprus   1        1     30400     0.856   (0.83, 0.859]
#
#         GDP_2015_faixas
# 9   (42404.95, 48373.8]
# 16  (36436.1, 42404.95]
# 25  (12560.7, 18529.55]
# 42  (18529.55, 24498.4]
# 44  (24498.4, 30467.25]

# %%
naoEuropeus=dfaixas[dfaixas['EU']==0]
naoEuropeus.head()
# Out:
#        country  EU  selecao  GDP_2015  IDH_2015 IDH_2015_faixas  \
# 0  Afghanistan   0        0      1750     0.479  (0.471, 0.501]
# 1      Albania   0        0     11000     0.764    (0.74, 0.77]
# 2      Algeria   0        0     13700     0.745    (0.74, 0.77]
# 3      Andorra   0        2     46600     0.858   (0.83, 0.859]
# 4       Angola   0        0      6230     0.533  (0.531, 0.561]
#
#        GDP_2015_faixas
# 0   (503.623, 6591.85]
# 1   (6591.85, 12560.7]
# 2  (12560.7, 18529.55]
# 3  (42404.95, 48373.8]
# 4   (503.623, 6591.85]

# %%
list(europeus)
# Out:
# ['country',
#  'EU',
#  'selecao',
#  'GDP_2015',
#  'IDH_2015',
#  'IDH_2015_faixas',
#  'GDP_2015_faixas']

# %%
numeurgdp=europeus['GDP_2015_faixas'].value_counts()
fig=plt.figure(figsize=(12,10))
numeurgdp.plot(kind='bar',  legend=False)

# %%
numeuridh=europeus['IDH_2015_faixas'].value_counts()
fig=plt.figure(figsize=(12,10))
numeuridh.plot(kind='bar',  legend=False)

# %% [markdown]
# Para a comparação com outros países, foram escolhidas as faixas  de valores que continham mais países da União Europeia

# %%
comparacao = naoEuropeus[((naoEuropeus['IDH_2015']>0.83)) & ((naoEuropeus['GDP_2015']>24498))]
comparacao
# Out:
#            country  EU  selecao  GDP_2015  IDH_2015 IDH_2015_faixas  \
# 3          Andorra   0        2     46600     0.858   (0.83, 0.859]
# 8        Australia   0        2     43800     0.939  (0.919, 0.949]
# 24          Brunei   0        2     74600     0.865  (0.859, 0.889]
# 30          Canada   0        2     43000     0.920  (0.919, 0.949]
# 74         Iceland   0        2     42700     0.921  (0.919, 0.949]
# 80          Israel   0        2     32000     0.899  (0.889, 0.919]
# 83           Japan   0        2     37800     0.903  (0.889, 0.919]
# 96   Liechtenstein   0        2     27000     0.912  (0.889, 0.919]
# 151    South Korea   0        2     28300     0.901  (0.889, 0.919]
#
#          GDP_2015_faixas
# 3    (42404.95, 48373.8]
# 8    (42404.95, 48373.8]
# 24   (72249.2, 78218.05]
# 30   (42404.95, 48373.8]
# 74   (42404.95, 48373.8]
# 80   (30467.25, 36436.1]
# 83   (36436.1, 42404.95]
# 96   (24498.4, 30467.25]
# 151  (24498.4, 30467.25]

# %% [markdown]
# Os Estados Unidos foram acrescentados ao dataframe por conta de seu reconhecimento internacional como um líder econômico mundial

# %%
naoEuropeus[naoEuropeus['country']=='United States']
# Out:
#            country  EU  selecao  GDP_2015  IDH_2015 IDH_2015_faixas  \
# 178  United States   0        2     15000      0.92  (0.919, 0.949]
#
#          GDP_2015_faixas
# 178  (12560.7, 18529.55]

# %% [markdown]
# Uma variável qualitativa foi acrescentada para selecionar os países filtrados acima. O número 0 indica aqueles países que a análise não levará em conta. 1 representa os que aderiram a União Europeia em 2004. 2 refere-se aos países que serão comparados no estudo

# %% [markdown]
# # Análise temporal

# %% [markdown]
# ### Seleção dos dados

# %% [markdown]
# A entrada dos países analisados no bloco ocorreu em 2004. Foi escolhido o período entre 2000 e 2008 para a análise, considerando que nesse intervalo de tempo seria possível obter uma perspectiva dos índices antes da aderência ao bloco e a mudança nos anos que sucederam a entrada.

# %% [markdown]
# ### Índices de desemprego

# %%
analise = unemployment.loc[:,[(2000),(2002),(2004),(2006),(2008)]]
analise.head()
# Out:
#    2000  2002  2004  2006   2008
# 0   NaN   NaN   NaN   NaN   2.49
# 1   NaN   NaN   NaN   NaN  13.10
# 2  29.8  25.9  17.6  12.3  11.30
# 3   NaN   NaN   NaN   NaN    NaN
# 4   NaN   NaN   NaN   NaN    NaN

# %%
paises= pd.read_excel('paises_UE.xlsx')

analisePaises=paises.join(analise, lsuffix='', rsuffix='')
analisePaises.tail()
# Out:
#        country  EU  selecao  2000  2002  2004  2006  2008
# 182  Venezuela   0        0  2.26  2.12  2.14   NaN  2.38
# 183    Vietnam   0        0   NaN   NaN   NaN   NaN   NaN
# 184      Yemen   0        0   NaN   NaN   NaN   NaN  7.93
# 185     Zambia   0        0   NaN   NaN  4.39   NaN   NaN
# 186   Zimbabwe   0        0   NaN   NaN   NaN   NaN   NaN

# %%
analiseUE=analisePaises[analisePaises['selecao']==1]
analiseUE
# Out:
#              country  EU  selecao   2000   2002   2004   2006   2008
# 44            Cyprus   1        1   4.48   4.27   5.20   3.90   3.43
# 45    Czech Republic   1        1    NaN    NaN    NaN    NaN    NaN
# 55           Estonia   1        1  10.20   8.70   8.91   8.45   7.06
# 73           Hungary   1        1    NaN    NaN    NaN    NaN    NaN
# 91            Latvia   1        1   1.27   1.45   2.40   2.46    NaN
# 97         Lithuania   1        1   3.00   3.48   3.54   3.32   3.34
# 105            Malta   1        1   8.46   6.80   8.17   7.38   3.98
# 133           Poland   1        1   6.97   8.11   7.72   7.27   5.79
# 147  Slovak Republic   1        1    NaN    NaN    NaN    NaN    NaN
# 148         Slovenia   1        1  30.20  33.50  29.60  28.50  22.40

# %%
analiseOutros=analisePaises[analisePaises['selecao']==2]
analiseOutros
# Out:
#            country  EU  selecao   2000   2002   2004   2006   2008
# 3          Andorra   0        2    NaN    NaN    NaN    NaN    NaN
# 8        Australia   0        2   4.69   4.85   5.83   5.24   4.13
# 24          Brunei   0        2  16.20  18.10  12.00   8.95   5.61
# 30          Canada   0        2    NaN    NaN    NaN    NaN    NaN
# 74         Iceland   0        2   4.32   4.22   4.49   4.41   6.77
# 80          Israel   0        2    NaN   9.33   8.40   7.79   6.63
# 83           Japan   0        2   0.80   1.10   1.70    NaN    NaN
# 96   Liechtenstein   0        2    NaN    NaN    NaN    NaN    NaN
# 151    South Korea   0        2  13.80  11.10  11.10   8.45  11.30
# 178  United States   0        2  13.30  16.90  13.00  10.80   8.03

# %% [markdown]
# É possível observar nos dados das tabelas que alguns países, tanto da União Europeia como fora dela, não possuem dados suficientes referentes para análise à evolução do desemprego.
# Por conta disso, optou-se por retirá-los da análise.
# Esses países foram:
#     Na europa:
#         -República Checa
#         -Hungária
#         -Eslováquia
#     Outros países:
#         -Andorra
#         -Canadá
#         -Liechtenstein

# %%
analiseUE.iloc[[0,2,4,5,6,7,9]]
# Out:
#        country  EU  selecao   2000   2002   2004   2006   2008
# 44      Cyprus   1        1   4.48   4.27   5.20   3.90   3.43
# 55     Estonia   1        1  10.20   8.70   8.91   8.45   7.06
# 91      Latvia   1        1   1.27   1.45   2.40   2.46    NaN
# 97   Lithuania   1        1   3.00   3.48   3.54   3.32   3.34
# 105      Malta   1        1   8.46   6.80   8.17   7.38   3.98
# 133     Poland   1        1   6.97   8.11   7.72   7.27   5.79
# 148   Slovenia   1        1  30.20  33.50  29.60  28.50  22.40

# %%
analiseOutros.iloc[[1,2,4,5,6,8,9]]
# Out:
#            country  EU  selecao   2000   2002   2004   2006   2008
# 8        Australia   0        2   4.69   4.85   5.83   5.24   4.13
# 24          Brunei   0        2  16.20  18.10  12.00   8.95   5.61
# 74         Iceland   0        2   4.32   4.22   4.49   4.41   6.77
# 80          Israel   0        2    NaN   9.33   8.40   7.79   6.63
# 83           Japan   0        2   0.80   1.10   1.70    NaN    NaN
# 151    South Korea   0        2  13.80  11.10  11.10   8.45  11.30
# 178  United States   0        2  13.30  16.90  13.00  10.80   8.03

# %%
faixa=range(2,18,2)

eu2000= pd.cut(analiseUE[2000], faixa, False)
ue1=(eu2000.value_counts(True)*100).round(decimals=1)
eu2000.value_counts()
# Out:
# [10, 12)    1
# [8, 10)     1
# [6, 8)      1
# [4, 6)      1
# [2, 4)      1
# [14, 16)    0
# [12, 14)    0
# Name: 2000, dtype: int64

# %% [markdown]
# ### Desemprego em 2000

# %%
faixa=range(2,18,2)

eu2000= pd.cut(analiseUE[2000], faixa, False)
ue1=(eu2000.value_counts(True)*100).round(decimals=1)
eu2000.value_counts()

fig=plt.figure(figsize=(15,5))
plt.subplot(121)
analiseUE[2000].plot.hist(color='turquoise',bins=faixa, density=True)
plt.xlabel('Expectativa')
plt.ylabel('Densidade')
plt.title(('Histograma'))


plt.subplot(122)
analiseOutros[2000].plot.hist(color=('indigo'),bins=faixa, density=True)
plt.xlabel('Expectativa')
plt.ylabel('Densidade')
plt.title(('Histograma'))

#fig=plt.figure(figsize=(15,5))
# Out:
# Text(0.5, 1.0, 'Histograma')

# %% [markdown]
# ### Desemprego em 2002

# %%
fig=plt.figure(figsize=(10,5))
plt.subplot(121)
analiseUE[2002].plot.hist(color='turquoise',bins=faixa, density=True)
plt.xlabel('Expectativa')
plt.ylabel('Densidade')
plt.title(('Histograma'))

plt.subplot(122)
analiseOutros[2002].plot.hist(color=('indigo'),bins=faixa, density=True)
plt.xlabel('Expectativa')
plt.ylabel('Densidade')
plt.title(('Histograma'))


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Desemprego em 2004

# %%
fig=plt.figure(figsize=(10,5))

plt.subplot(121)
analiseUE[2004].plot.hist(color='turquoise',bins=faixa, density=True)
plt.xlabel('Desemprego')
plt.ylabel('Densidade')
plt.title(('Nível de desemprego  de 2004'))


plt.subplot(122)
analiseOutros[2004].plot.hist(color=('indigo'),bins=faixa, density=True)
plt.xlabel('Expectativa')
plt.ylabel('Densidade')
plt.title(('Histograma'))


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Desemprego em 2006

# %%
fig=plt.figure(figsize=(10,5))
plt.subplot(121)
analiseUE[2006].plot.hist(color='turquoise',bins=faixa, density=True)
plt.xlabel('Desemprego')
plt.ylabel('Densidade')
plt.title(('Nível de desemprego  de 2006'))

plt.subplot(122)
analiseOutros[2006].plot.hist(color=('indigo'),bins=faixa, density=True)
plt.xlabel('Expectativa')
plt.ylabel('Densidade')
plt.title(('Histograma'))
# Out:
# Text(0.5, 1.0, 'Histograma')

# %% [markdown]
# ### Desemprego em 2008

# %%
fig=plt.figure(figsize=(10,5))
plt.subplot(121)
analiseUE[2008].plot.hist(color='turquoise',bins=faixa, density=True)
plt.xlabel('Desemprego')
plt.ylabel('Densidade')
plt.title(('Nível de desemprego  de 2008'))

plt.subplot(122)
analiseOutros[2008].plot.hist(color=('indigo'),bins=faixa, density=True)
plt.xlabel('Expectativa')
plt.ylabel('Densidade')
plt.title(('Histograma'))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Análise do mecanismo

# %% [markdown]
# Na análise do desemprego, ficou claro que esse índice sofreu alterações ao longo dos anos. Em um período de apenas quatro anos, o desemprego diminuiu em países que aderiram à União Europeia.

# %% [markdown]
# Na seguinte parte da análise, serão investigados os possíveis motivos para essa diminuição. Para o estudo do índice de investimento interno, índice de exportação e crescimento anual do GDP, foi escolhido o ano de 2008. O motivo para tal escolha é que em 2008 a União Europeia já contava com 28 países membros. Além disso, após quatro anos, é esperado que os índices escolhidos já tenham sofrido alterações nos países que entraram no bloco em 2004, devido à adaptação comercial e estrutural decorrente da entrada no bloco.

# %% [markdown]
# O objetivo é analisar a relação do desemprego com as características econômicas e estruturais escolhidas.

# %% [markdown]
# ### Índice de investimento interno

# %%
invest = investimento.loc[:,[(2008)]]
invest = invest.rename(columns = {2008:'Investimento_2008'})
invest.head()
# Out:
#    Investimento_2008
# 0               18.9
# 1               35.8
# 2               37.3
# 3               16.2
# 4               19.6

# %% [markdown]
# ### Crescimento anual do GDP

# %%
crescimento_gdp = dGDP.loc[:,[(2008)]]
crescimento_gdp = crescimento_gdp.rename(columns = {2008:'CrescimentoGDP_2008'})
crescimento_gdp.head()
# Out:
#    CrescimentoGDP_2008
# 0                 2.50
# 1                 7.24
# 2                 2.02
# 3                -4.22
# 4                13.80

# %% [markdown]
# ### Índice de exportação

# %%
export = exportacao.loc[:,[(2008)]]
export = export.rename(columns = {2008:'Exportacao_2008'})
export.head()
# Out:
#    Exportacao_2008
# 0             18.0
# 1             25.3
# 2             48.0
# 3             76.3
# 4             45.7

# %% [markdown]
# ### Desemprego

# %%
analisePaises
# Out:
#      Desemprego_2008
# 0               2.49
# 1              13.10
# 2              11.30
# 3                NaN
# 4                NaN
# 5               7.84
# 6                NaN
# 7               4.23
# 8               4.13
# 9               6.05
# 10              8.18
# 11               NaN
# 12               NaN
# 13              8.12
# 14               NaN
# 15              6.98
# 16              8.18
# 17               NaN
# 18               NaN
# 19               NaN
# 20             23.40
# 21               NaN
# 22               NaN
# 23               NaN
# 24              5.61
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29              6.14
# ..               ...
# 157              NaN
# 158              NaN
# 159             6.23
# 160             3.35
# 161            10.90
# 162              NaN
# 163              NaN
# 164             1.18
# 165              NaN
# 166              NaN
# 167              NaN
# 168             4.63
# 169            12.40
# 170             9.71
# 171              NaN
# 172              NaN
# 173              NaN
# 174             6.36
# 175              NaN
# 176             5.62
# 177             5.78
# 178             8.03
# 179             4.89
# 180              NaN
# 181             6.25
# 182             2.38
# 183              NaN
# 184             7.93
# 185              NaN
# 186              NaN
#
# [187 rows x 1 columns]

# %%
analisePaises=analisePaises.loc[:,[(2008)]]
analisePaises = analisePaises.rename(columns = {2008:'Desemprego_2008'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-25d835a50049> in <module>
# ----> 1 analisePaises=analisePaises.loc[:,[(2008)]]
#       2 analisePaises = analisePaises.rename(columns = {2008:'Desemprego_2008'})
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1141             if labels.is_unique and Index(keyarr).is_unique:
#    1142                 indexer = ax.get_indexer_for(key)
# -> 1143                 self._validate_read_indexer(key, indexer, axis)
#    1144
#    1145                 d = {axis: [ax.reindex(keyarr)[0], indexer]}
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1204                 raise KeyError(
#    1205                     u"None of [{key}] are in the [{axis}]".format(
# -> 1206                         key=key, axis=self.obj._get_axis_name(axis)))
#    1207
#    1208             # we skip the warning on Categorical/Interval
#
# KeyError: 'None of [[2008]] are in the [columns]'

# %% [markdown]
# ### Inner join

# %%
df=paises.join(invest, lsuffix='', rsuffix='')
df=df.join(export, lsuffix='', rsuffix='')
df=df.join(crescimento_gdp, lsuffix='', rsuffix='')
df=df.join(analisePaises, lsuffix='', rsuffix='')
data=df[(df['EU']==1)]
data
# Out:
#              country  EU  selecao  Investimento_2008  Exportacao_2008  \
# 9            Austria   1        0               29.4            65.80
# 16           Belgium   1        0               20.4            62.40
# 25          Bulgaria   1        0               26.7             9.97
# 42           Croatia   1        0               28.9            20.60
# 44            Cyprus   1        1               24.0            63.20
# 45    Czech Republic   1        1                NaN            54.20
# 46           Denmark   1        0               30.0              NaN
# 55           Estonia   1        1               25.1              NaN
# 58           Finland   1        0               15.9            28.10
# 59            France   1        0               26.0            62.20
# 63           Germany   1        0               16.4            25.00
# 65            Greece   1        0               12.8            25.20
# 73           Hungary   1        1               41.8            41.20
# 79           Ireland   1        0               24.5            38.50
# 81             Italy   1        0               27.5            41.90
# 91            Latvia   1        1               29.8            39.00
# 97         Lithuania   1        1               21.5            43.20
# 98        Luxembourg   1        0               24.2            26.50
# 105            Malta   1        1               39.2            45.90
# 118      Netherlands   1        0               26.1            71.60
# 133           Poland   1        1               24.0            37.90
# 134         Portugal   1        0               27.3            31.10
# 136          Romania   1        0               30.3            26.30
# 147  Slovak Republic   1        1               29.6            66.10
# 148         Slovenia   1        1               27.6            44.30
# 153            Spain   1        0               25.3            25.30
# 161           Sweden   1        0               26.0            62.70
# 177   United Kingdom   1        0                NaN            30.20
#
#      CrescimentoGDP_2008  Desemprego_2008
# 9                  1.390             6.05
# 16                 0.809             8.18
# 25                 5.980              NaN
# 42                 1.950             3.65
# 44                 2.250             3.43
# 45                 2.800              NaN
# 46                -0.795              NaN
# 55                -4.100             7.06
# 58                 0.296              NaN
# 59                -0.060             7.52
# 63                 0.926              NaN
# 65                -1.490              NaN
# 73                 0.746              NaN
# 79                -3.120            12.70
# 81                -1.310              NaN
# 91                -2.970              NaN
# 97                 2.860             3.34
# 98                -0.191              NaN
# 105                3.590             3.98
# 118                3.460              NaN
# 133                6.690             5.79
# 134                6.160             6.21
# 136                3.840              NaN
# 147                3.680              NaN
# 148                4.330            22.40
# 153                3.690              NaN
# 161                3.180            10.90
# 177                4.670             5.78

# %%
data.plot.scatter(x='CrescimentoGDP_2008',y='Desemprego_2008');
sns.regplot(data["CrescimentoGDP_2008"],data["Desemprego_2008"], color=('indigo'))
plt.grid()
# Out:
# C:\Users\gabic\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data=df[(df['EU']==1)]
newdata=data.drop(148)
#newdata=newdata.drop(79)

newdata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-6a5b5efbfc6d> in <module>
# ----> 1 data=df[(df['EU']==1)]
#       2 newdata=data.drop(148)
#       3 #newdata=newdata.drop(79)
#       4
#       5 newdata
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Gráficos e análise dos resultados

# %%
newdata.plot.scatter(x='CrescimentoGDP_2008',y='Desemprego_2008');
sns.regplot(newdata["CrescimentoGDP_2008"],newdata["Desemprego_2008"], color=('indigo'))
plt.grid()
# Out:
# C:\Users\gabic\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# outliners

# %%
print('A correlação é:', newdata['CrescimentoGDP_2008'].corr(newdata['Desemprego_2008']))
# Out:
# A correlação é: -0.5572867239227255

# %%
newdata.plot.scatter(x='Exportacao_2008',y='Desemprego_2008');
sns.regplot(newdata["Exportacao_2008"],newdata["Desemprego_2008"], color=('goldenrod'))
plt.grid()

# %%
print('A correlação é:', newdata['Desemprego_2008'].corr(newdata['Exportacao_2008']))
# Out:
# A correlação é: 0.08492391456762774

# %%
newdata.plot.scatter(x='Exportacao_2008',y='Desemprego_2008');
sns.regplot(newdata["Investimento_2008"],newdata["Desemprego_2008"], color=('turquoise'))
plt.grid()

# %%
print('A correlação é:', newdata['Desemprego_2008'].corr(newdata['Investimento_2008']))
# Out:
# A correlação é: -0.28222088694452513

# %%
unemployment.head()
# Out:
#                country  1947  1948  1949  1950  1951  1952  1953  1954  1955  \
# 0          Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2              Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3               Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  Antigua and Barbuda   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...    2008  2009   2010   2011   2012   2013  2014  2015  2016  2017
# 0  ...    2.49   NaN    NaN    NaN   1.69    NaN   NaN   NaN   NaN   NaN
# 1  ...   13.10  13.7  14.10  13.50  13.40  15.90  17.5  17.1  15.2  13.8
# 2  ...   11.30  10.2   9.96   9.96  11.00   9.82  10.2  11.2  10.2  13.6
# 3  ...     NaN   NaN   9.43  16.80    NaN    NaN   NaN   NaN   NaN   NaN
# 4  ...     NaN   NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 72 columns]

# %%
unemployment=pd.read_excel('unemployment.xlsx')


invest = investimento.loc[:,[(2006)]]
invest = invest.rename(columns = {2004:'Investimento_2012'})
crescimento_gdp = dGDP.loc[:,[(2004)]]
crescimento_gdp = crescimento_gdp.rename(columns = {2004:'CrescimentoGDP_2012'})
export = exportacao.loc[:,[(2004)]]
export = export.rename(columns = {2004:'Exportacao_2012'})
unemployment=unemployment.loc[:,[(2004)]]
unemployment = unemployment.rename(columns = {2004:'Desemprego_2012'})
df=paises.join(invest, lsuffix='', rsuffix='')
df=df.join(export, lsuffix='', rsuffix='')
df=df.join(crescimento_gdp, lsuffix='', rsuffix='')
df=df.join(unemployment, lsuffix='', rsuffix='')
data=df[(df['EU']==1)]
data
# Out:
#              country  EU  selecao   2006  Exportacao_2012  \
# 9            Austria   1        0  33.50             48.8
# 16           Belgium   1        0  19.00             50.6
# 25          Bulgaria   1        0  22.00             11.3
# 42           Croatia   1        0  24.60             16.0
# 44            Cyprus   1        1  24.30             57.3
# 45    Czech Republic   1        1    NaN             43.9
# 46           Denmark   1        0  26.90              NaN
# 55           Estonia   1        1  24.00              NaN
# 58           Finland   1        0  24.30             26.5
# 59            France   1        0  30.90             55.0
# 63           Germany   1        0  20.80             39.3
# 65            Greece   1        0   9.99             33.0
# 73           Hungary   1        1  38.60             32.6
# 79           Ireland   1        0  24.70             39.1
# 81             Italy   1        0  33.90             37.5
# 91            Latvia   1        1  21.00             36.2
# 97         Lithuania   1        1  22.70             30.7
# 98        Luxembourg   1        0  21.20             32.6
# 105            Malta   1        1  32.70             25.6
# 118      Netherlands   1        0  24.20             63.5
# 133           Poland   1        1  16.80             34.3
# 134         Portugal   1        0  22.20             27.3
# 136          Romania   1        0  25.00             35.6
# 147  Slovak Republic   1        1  31.30             55.0
# 148         Slovenia   1        1  28.00             30.9
# 153            Spain   1        0  25.20             25.2
# 161           Sweden   1        0  23.40             51.5
# 177   United Kingdom   1        0    NaN             32.1
#
#      CrescimentoGDP_2012  Desemprego_2012
# 9                  2.830             8.00
# 16                 3.350              NaN
# 25                 6.900              NaN
# 42                 3.230             4.33
# 44                 3.670             5.20
# 45                 4.540              NaN
# 46                 2.180              NaN
# 55                 8.750             8.91
# 58                 3.800              NaN
# 59                 2.270            10.70
# 63                 1.080             2.97
# 65                 4.820              NaN
# 73                 4.810              NaN
# 79                 5.090              NaN
# 81                 0.864              NaN
# 91                 8.570             2.40
# 97                 7.190             3.54
# 98                 4.070              NaN
# 105                0.125             8.17
# 118                7.350              NaN
# 133                2.860             7.72
# 134                3.490             7.76
# 136                6.480              NaN
# 147                6.060              NaN
# 148                8.090            29.60
# 153                4.470              NaN
# 161                7.640              NaN
# 177                5.910             5.53

# %%
data=df[(df['EU']==1)]

newdata=data.drop(148)
newdata
# Out:
#              country  EU  selecao   2006  Exportacao_2012  \
# 9            Austria   1        0  33.50             48.8
# 16           Belgium   1        0  19.00             50.6
# 25          Bulgaria   1        0  22.00             11.3
# 42           Croatia   1        0  24.60             16.0
# 44            Cyprus   1        1  24.30             57.3
# 45    Czech Republic   1        1    NaN             43.9
# 46           Denmark   1        0  26.90              NaN
# 55           Estonia   1        1  24.00              NaN
# 58           Finland   1        0  24.30             26.5
# 59            France   1        0  30.90             55.0
# 63           Germany   1        0  20.80             39.3
# 65            Greece   1        0   9.99             33.0
# 73           Hungary   1        1  38.60             32.6
# 79           Ireland   1        0  24.70             39.1
# 81             Italy   1        0  33.90             37.5
# 91            Latvia   1        1  21.00             36.2
# 97         Lithuania   1        1  22.70             30.7
# 98        Luxembourg   1        0  21.20             32.6
# 105            Malta   1        1  32.70             25.6
# 118      Netherlands   1        0  24.20             63.5
# 133           Poland   1        1  16.80             34.3
# 134         Portugal   1        0  22.20             27.3
# 136          Romania   1        0  25.00             35.6
# 147  Slovak Republic   1        1  31.30             55.0
# 153            Spain   1        0  25.20             25.2
# 161           Sweden   1        0  23.40             51.5
# 177   United Kingdom   1        0    NaN             32.1
#
#      CrescimentoGDP_2012  Desemprego_2012
# 9                  2.830             8.00
# 16                 3.350              NaN
# 25                 6.900              NaN
# 42                 3.230             4.33
# 44                 3.670             5.20
# 45                 4.540              NaN
# 46                 2.180              NaN
# 55                 8.750             8.91
# 58                 3.800              NaN
# 59                 2.270            10.70
# 63                 1.080             2.97
# 65                 4.820              NaN
# 73                 4.810              NaN
# 79                 5.090              NaN
# 81                 0.864              NaN
# 91                 8.570             2.40
# 97                 7.190             3.54
# 98                 4.070              NaN
# 105                0.125             8.17
# 118                7.350              NaN
# 133                2.860             7.72
# 134                3.490             7.76
# 136                6.480              NaN
# 147                6.060              NaN
# 153                4.470              NaN
# 161                7.640              NaN
# 177                5.910             5.53

# %%
newdata.plot.scatter(x='CrescimentoGDP_2012',y='Desemprego_2012');
sns.regplot(newdata["CrescimentoGDP_2012"],newdata["Desemprego_2012"], color=('indigo'))
plt.grid()

# %%
print('A correlação é:', newdata['CrescimentoGDP_2012'].corr(newdata['Desemprego_2012']))
# Out:
# A correlação é: -0.2851510263476525

# %%
newdata.plot.scatter(x='Exportacao_2012',y='Desemprego_2012');
sns.regplot(newdata["Exportacao_2012"],newdata["Desemprego_2012"], color=('goldenrod'))
plt.grid()

# %%
print('A correlação é:', newdata['Desemprego_2012'].corr(newdata['Exportacao_2012']))
# Out:
# A correlação é: 0.2834305430565268

# %%
newdata.plot.scatter(x='Investimento_2012',y='Desemprego_2012');
sns.regplot(newdata["Investimento_2012"],newdata["Desemprego_2012"], color=('indigo'))
plt.grid()

print('A correlação é:', newdata['Desemprego_2012'].corr(newdata['Investimento_2012']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2012'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-1cff37cb253a> in <module>
# ----> 1 newdata.plot.scatter(x='Investimento_2012',y='Desemprego_2012');
#       2 sns.regplot(newdata["Investimento_2012"],newdata["Desemprego_2012"], color=('indigo'))
#       3 plt.grid()
#       4
#       5 print('A correlação é:', newdata['Desemprego_2012'].corr(newdata['Investimento_2012']))
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     817         if is_integer(y) and not self.data.columns.holds_integer():
#     818             y = self.data.columns[y]
# --> 819         if len(self.data[x]._get_numeric_data()) == 0:
#     820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2012'

# %%
data=df[(df['EU']==1)]

data

# %%
data.plot.scatter(x='Desemprego_2008',y='Exportacao_2008');
sns.regplot(data["Desemprego_2008"],data["Exportacao_2008"], color=('turquoise'))
plt.grid()

# %%
data=df[(df['EU']==1)]
ndata=data.drop(148)
ndata=ndata.drop(79)
ndata

# %%
ndata.plot.scatter(x='Exportacao_2008',y='Desemprego_2008');
sns.regplot(ndata["Exportacao_2008"],ndata["Desemprego_2008"], color=('turquoise'))
plt.grid()

# %%
print('A correlação é:', data['Desemprego_2008'].corr(data['Exportacao_2008']))

# %%
data.plot.scatter(x='Desemprego_2008',y='Exportacao_2008');
sns.regplot(data["Desemprego_2008"],data["Exportacao_2008"], color=('turquoise'))
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Desemprego_2008'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-e568abd51c6c> in <module>
# ----> 1 data.plot.scatter(x='Desemprego_2008',y='Exportacao_2008');
#       2 sns.regplot(data["Desemprego_2008"],data["Exportacao_2008"], color=('turquoise'))
#       3 plt.grid()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     817         if is_integer(y) and not self.data.columns.holds_integer():
#     818             y = self.data.columns[y]
# --> 819         if len(self.data[x]._get_numeric_data()) == 0:
#     820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Desemprego_2008'

# %%
print('A correlação é:', data['CrescimentoGDP_2008'].corr(data['Desemprego_2008']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CrescimentoGDP_2008'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-62025f3bd016> in <module>
# ----> 1 print('A correlação é:', data['CrescimentoGDP_2008'].corr(data['Desemprego_2008']))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CrescimentoGDP_2008'

# %%
data.plot.scatter(x='Desemprego_2008',y='Investimento_2008');
sns.regplot(data["Desemprego_2008"],data["Investimento_2008"], color=('turquoise'))
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Desemprego_2008'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-e366fddc92d1> in <module>
# ----> 1 data.plot.scatter(x='Desemprego_2008',y='Investimento_2008');
#       2 sns.regplot(data["Desemprego_2008"],data["Investimento_2008"], color=('turquoise'))
#       3 plt.grid()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     817         if is_integer(y) and not self.data.columns.holds_integer():
#     818             y = self.data.columns[y]
# --> 819         if len(self.data[x]._get_numeric_data()) == 0:
#     820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Desemprego_2008'

# %%
print('A correlação é:', data['Investimento_2008'].corr(data['Desemprego_2008']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2008'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-5089c978f753> in <module>
# ----> 1 print('A correlação é:', data['Investimento_2008'].corr(data['Desemprego_2008']))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2008'

# %%
print('A correlação é:', data['Investimento_2008'].corr(data['Exportacao_2008']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2008'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-eaba556205fa> in <module>
# ----> 1 print('A correlação é:', data['Investimento_2008'].corr(data['Exportacao_2008']))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2008'

# %%
print('A correlação é:', data['Investimento_2008'].corr(data['CrescimentoGDP_2008']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2008'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-23a3533fe6dd> in <module>
# ----> 1 print('A correlação é:', data['Investimento_2008'].corr(data['CrescimentoGDP_2008']))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Investimento_2008'

# %%
print('A correlação é:', data['Exportacao_2008'].corr(data['CrescimentoGDP_2008']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Exportacao_2008'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-cf9b4f3ed254> in <module>
# ----> 1 print('A correlação é:', data['Exportacao_2008'].corr(data['CrescimentoGDP_2008']))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Exportacao_2008'

# %%
print('A correlação é:', data['Exportacao_2008'].corr(data['Investimento_2008']))
# Out:
# A correlação é: -0.0736362568401191

# %%
print('A correlação é:', data['Desemprego_2008'].corr(data['Investimento_2008']))
# Out:
# A correlação é: -0.13411861508591247

# %% [markdown]
# ## Conclusão
